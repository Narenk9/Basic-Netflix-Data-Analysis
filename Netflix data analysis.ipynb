# %% [markdown]
# # Netflix data analysis
# ## Data taken from Kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/naren/OneDrive/Desktop/project 1DS/intern/netflix_titles.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Subsetting rows

# %%
df[['title','release_year','date_added']].tail() # selecting multiple colums
# Out:
#             title  release_year         date_added
# 8802       Zodiac          2007  November 20, 2019
# 8803  Zombie Dumb          2018       July 1, 2019
# 8804   Zombieland          2009   November 1, 2019
# 8805         Zoom          2006   January 11, 2020
# 8806       Zubaan          2015      March 2, 2019

# %%
df.loc[4] # we get all data of 3rd row
# Out:
# show_id                                                        s5
# type                                                      TV Show
# title                                                Kota Factory
# director                                                      NaN
# cast            Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# country                                                     India
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in       International TV Shows, Romantic TV Shows, TV ...
# description     In a city of coaching centers known to train I...
# Name: 4, dtype: object

# %%
df.loc[[0,99,999]]  # subsetting multiple rows at a time 1st , 100th and 1000th row
# Out:
#     show_id     type                 title         director  \
# 0        s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 99     s100  TV Show          On the Verge              NaN
# 999   s1000    Movie              Stowaway        Joe Penna
#
#                                                   cast  \
# 0                                                  NaN
# 99   Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
# 999  Anna Kendrick, Toni Collette, Daniel Dae Kim, ...
#
#                     country          date_added  release_year rating  \
# 0             United States  September 25, 2021          2020  PG-13
# 99    France, United States   September 7, 2021          2021  TV-MA
# 999  Germany, United States      April 22, 2021          2021  TV-MA
#
#      duration                                listed_in  \
# 0      90 min                            Documentaries
# 99   1 Season                   TV Comedies, TV Dramas
# ...

# %%
df.iloc[4] # in iloc we can pass -1 but not possible in loc command
# Out:
# show_id                                                        s5
# type                                                      TV Show
# title                                                Kota Factory
# director                                                      NaN
# cast            Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# country                                                     India
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in       International TV Shows, Romantic TV Shows, TV ...
# description     In a city of coaching centers known to train I...
# Name: 4, dtype: object

# %%
df.iloc[-1] # get last row data
# Out:
# show_id                                                     s8807
# type                                                        Movie
# title                                                      Zubaan
# director                                              Mozez Singh
# cast            Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# country                                                     India
# date_added                                          March 2, 2019
# release_year                                                 2015
# rating                                                      TV-14
# duration                                                  111 min
# listed_in          Dramas, International Movies, Music & Musicals
# description     A scrappy but poor boy worms his way into a ty...
# Name: 8806, dtype: object

# %% [markdown]
# # Subsetting columns

# %%
df.loc[4:5,['title','country']]
# Out:
#            title country
# 4   Kota Factory   India
# 5  Midnight Mass     NaN

# %%
#df.iloc[4:9,[2,4,-1]] # in iloc you can use integers for subsetting columns
df.iloc[4:9,range(2,8)]
# Out:
#                               title                       director  \
# 4                      Kota Factory                            NaN
# 5                     Midnight Mass                  Mike Flanagan
# 6  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7                           Sankofa                   Haile Gerima
# 8     The Great British Baking Show                Andy Devonshire
#
#                                                 cast  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# ...

# %% [markdown]
# # Subsetting both rows and columns

# %%
df.loc[4,'title']
# Out:
# 'Kota Factory'

# %%
df.iloc[4,2] # uses integer
# Out:
# 'Kota Factory'

# %%
# multiple diff subsetting of rows and columns
# In case of loc df.loc[2;6,['title','cast','date_added']]
df.iloc[[2,4,6,23],[2,4,6,7]]
# Out:
#                                            title  \
# 2                                      Ganglands
# 4                                   Kota Factory
# 6               My Little Pony: A New Generation
# 23  Go! Go! Cory Carson: Chrissy Takes the Wheel
#
#                                                  cast          date_added  \
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  September 24, 2021
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...  September 24, 2021
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...  September 24, 2021
# 23  Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...  September 21, 2021
#
#     release_year
# 2           2021
# 4           2021
# 6           2021
# 23          2021

# %% [markdown]
# # Groupby means

# %%
df.groupby(['country','rating']).count()
#df.\groupby(['year', 'continent'])\[['lifeExp', 'gdpPercap']].\mean()
# Out:
#                           show_id  type  title  director  cast  date_added  \
# country           rating
# , France, Algeria TV-14         1     1      1         1     1           1
# , South Korea     TV-MA         1     1      1         0     1           1
# Argentina         NR            2     2      2         2     2           2
#                   R             1     1      1         1     1           1
#                   TV-14         7     7      7         6     4           7
# ...                           ...   ...    ...       ...   ...         ...
# Vietnam           TV-14         3     3      3         3     3           3
#                   TV-G          1     1      1         1     1           1
#                   TV-MA         3     3      3         3     3           3
# West Germany      TV-MA         1     1      1         1     0           1
# Zimbabwe          TV-G          1     1      1         1     1           1
#
# ...

# %%
df.groupby(['release_year', 'country'])['rating'].count()
# Out:
# release_year  country
# 1942          United States                    2
# 1943          United States                    3
# 1944          United States                    2
#               United States, United Kingdom    1
# 1945          United States                    4
#                                               ..
# 2021          United States, Mexico            1
#               United States, Singapore         1
#               United States, United Kingdom    4
#               Uruguay, Germany                 1
#               Vietnam                          1
# Name: rating, Length: 1754, dtype: int64

# %%
df.columns
#reset_index to flatten dataframe
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Grouped frequency counts

# %%
hi =df.groupby('rating')['release_year'].nunique()
hi.plot()
# Out:
# <AxesSubplot:xlabel='rating'>

# %% [markdown]
# # Cleaning

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isna().any() #gives a boolean value 
# if any null value is present or not,
#but it gives results column-wise, not in tabular format.
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
df.isna().sum() 
# gives the sum of the null values preset in the dataset column-wise.
# or df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
mis_value_percent = 100 * df.isnull().sum() / len(df)
mis_value_percent
#the percentage of them against the total values.
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df.groupby('release_year').count()
# Out:
#               show_id  type  title  director  cast  country  date_added  \
# release_year
# 1925                1     1      1         0     0        0           1
# 1942                2     2      2         2     1        2           2
# 1943                3     3      3         3     0        3           3
# 1944                3     3      3         3     1        3           3
# 1945                4     4      4         3     1        4           4
# ...               ...   ...    ...       ...   ...      ...         ...
# 2017             1032  1032   1032       773   912      966        1032
# 2018             1147  1147   1147       760  1026     1038        1146
# 2019             1030  1030   1030       629   917      913        1030
# 2020              953   953    953       548   827      852         953
# 2021              592   592    592       297   494      383         592
#
#               rating  duration  listed_in  description
# release_year
# ...

# %%
df['type']= [1 if x=="Movie" else 0 for x in df["type"]]
# movie =1

# %%
df['type']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 8802    1
# 8803    0
# 8804    1
# 8805    1
# 8806    1
# Name: type, Length: 8807, dtype: int64

# %%
df['date_added'] = pd.to_datetime(df['date_added']) #change into normal format

# %%
df['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df
# Out:
#      show_id  type                  title         director  \
# 0         s1     1   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2     0          Blood & Water              NaN
# 2         s3     0              Ganglands  Julien Leclercq
# 3         s4     0  Jailbirds New Orleans              NaN
# 4         s5     0           Kota Factory              NaN
# ...      ...   ...                    ...              ...
# 8802   s8803     1                 Zodiac    David Fincher
# 8803   s8804     0            Zombie Dumb              NaN
# 8804   s8805     1             Zombieland  Ruben Fleischer
# 8805   s8806     1                   Zoom     Peter Hewitt
# 8806   s8807     1                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['rating'].isnull().sum()
# Out:
# 4

# %%
df.nunique()
# here all titles are unique/ but directors,cast and many more are duplicates
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1714
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['director'].duplicated().sum()
# Out:
# 4278

# %%
# make a copy of data
netflix =df.copy()

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
#drop null values
netflix =netflix.dropna()
netflix.shape
# Out:
# (5332, 12)

# %%
netflix.head()
# Out:
#    show_id  type                          title             director  \
# 7       s8     1                        Sankofa         Haile Gerima
# 8       s9     0  The Great British Baking Show      Andy Devonshire
# 9      s10     1                   The Starling       Theodore Melfi
# 12     s13     1                   Je Suis Karl  Christian Schwochow
# 24     s25     1                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                      United Kingdom 2021-09-24
# ...

# %% [markdown]
# # Data visualization

# %%
import seaborn as sns

# %%
sns.countplot(netflix['type'])
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.title('Type')
# Out:
# C:\Users\naren\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type')

# %%
sns.countplot(netflix['rating'])
sns.countplot(netflix['rating']).set_xticklabels(sns.countplot(netflix['rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Rating')
# Out:
# C:\Users\naren\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\naren\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\naren\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
netflix
# Out:
#      show_id  type                          title             director  \
# 7         s8     1                        Sankofa         Haile Gerima
# 8         s9     0  The Great British Baking Show      Andy Devonshire
# 9        s10     1                   The Starling       Theodore Melfi
# 12       s13     1                   Je Suis Karl  Christian Schwochow
# 24       s25     1                          Jeans           S. Shankar
# ...      ...   ...                            ...                  ...
# 8801   s8802     1                        Zinzana      Majid Al Ansari
# 8802   s8803     1                         Zodiac        David Fincher
# 8804   s8805     1                     Zombieland      Ruben Fleischer
# 8805   s8806     1                           Zoom         Peter Hewitt
# 8806   s8807     1                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...

# %%
netflix.describe()
# Out:
#               type  release_year
# count  5332.000000   5332.000000
# mean      0.972431   2012.742123
# std       0.163751      9.625831
# min       0.000000   1942.000000
# 25%       1.000000   2011.000000
# 50%       1.000000   2016.000000
# 75%       1.000000   2018.000000
# max       1.000000   2021.000000

# %%
df['country'].groupby(df['country']).count().sort_values(ascending=False)
# Out:
# country
# United States                                                                          2818
# India                                                                                   972
# United Kingdom                                                                          419
# Japan                                                                                   245
# South Korea                                                                             199
#                                                                                        ...
# Ireland, Canada, Luxembourg, United States, United Kingdom, Philippines, India            1
# Ireland, Canada, United Kingdom, United States                                            1
# Ireland, Canada, United States, United Kingdom                                            1
# Ireland, France, Iceland, United States, Mexico, Belgium, United Kingdom, Hong Kong       1
# ...

# %% [markdown]
# # Using Pandas Profiling

# %%
from pandas_profiling import ProfileReport
pd.set_option('display.max_colwidth',None)
# %matplotlib inline
profile = ProfileReport(df, minimal=True)
profile.to_file(output_file="output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## df.rename(columns ={"col1":"col3"})
#
# ## df["col1"] = df["col2"] + 5
#
# ## filter data frame df[df['Percentage'] > 70] or df.loc[df['Percentage'] > 70]
#
# ## df.loc[(df['Age'] == 22) & df['Stream'].isin(['Commerce', 'Science'] )]

# %%
df.country.value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
df.loc[(df['country'] == 'India')]
# Out:
#      show_id  type                          title                 director  \
# 4         s5     0                   Kota Factory                      NaN
# 24       s25     1                          Jeans               S. Shankar
# 39       s40     0                   Chhota Bheem                      NaN
# 50       s51     0                  Dharmakshetra                      NaN
# 66       s67     0  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...   ...                            ...                      ...
# 8773   s8774     1            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776     0                Yeh Meri Family                      NaN
# 8798   s8799     1                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800     1                          Zenda           Avadhoot Gupte
# 8806   s8807     1                         Zubaan              Mozez Singh
#
# ...

# %%
df.loc[(df['release_year']>2020)]
# Out:
#      show_id  type                      title         director  \
# 1         s2     0              Blood & Water              NaN
# 2         s3     0                  Ganglands  Julien Leclercq
# 3         s4     0      Jailbirds New Orleans              NaN
# 4         s5     0               Kota Factory              NaN
# 5         s6     0              Midnight Mass    Mike Flanagan
# ...      ...   ...                        ...              ...
# 1468   s1469     1  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552     0                      Hilda              NaN
# 1696   s1697     0               Polly Pocket              NaN
# 2920   s2921     0              Love Is Blind              NaN
# 8437   s8438     0     The Netflix Afterparty              NaN
#
# ...
